# %% [markdown]
# <a href="https://colab.research.google.com/github/one-2730/ESSA-25-1/blob/Session/ESAA_OB_250314_Session.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **모델 훈련 연습 문제**
# ___
# - 출처 : 핸즈온 머신러닝 Ch04 연습문제 1, 5, 9, 10
# - 개념 문제의 경우 텍스트 셀을 추가하여 정답을 적어주세요.

# %% [markdown]
# ### **1. 수백만 개의 특성을 가진 훈련 세트에서는 어떤 선형 회귀 알고리즘을 사용할 수 있을까요?**
# ___
# 확률적 경사하강법, 미니배치 경사하강법

# %% [markdown]
# ### **2. 배치 경사 하강법을 사용하고 에포크마다 검증 오차를 그래프로 나타내봤습니다. 검증 오차가 일정하게 상승되고 있다면 어떤 일이 일어나고 있는 걸까요? 이 문제를 어떻게 해결할 수 있나요?**
# ___
#
# 모델이 과대적합되고 있음을 알 수 있다. 학습률을 낮추거나 조기종료, 에포크 크기 변경을 시도할 수 있다

# %% [markdown]
# ### **3. 릿지 회귀를 사용했을 때 훈련 오차가 검증 오차가 거의 비슷하고 둘 다 높았습니다. 이 모델에는 높은 편향이 문제인가요, 아니면 높은 분산이 문제인가요? 규제 하이퍼파라미터 $\alpha$를 증가시켜야 할까요 아니면 줄여야 할까요?**
# ___
#
# 편향이 높고 분산이 낮다.
# 편향이 높아서 모델 복잡도를 높이기 위해 규제를 낮춰야 한다. 즉, alpha를 줄여야 한다

# %% [markdown]
# ### **4. 다음과 같이 사용해야 하는 이유는?**
# ___
# - 평범한 선형 회귀(즉, 아무런 규제가 없는 모델) 대신 릿지 회귀
#   -> 과대 적합을 방지하기 위해서
# - 릿지 회귀 대신 라쏘 회귀 -> 릿지가 기본이지만 쓰이는 특성이 몇개 뿐이라고 의심될 때
# - 라쏘 회귀 대신 엘라스틱넷-> 특성 수가 훈련샘플보다 많거나 특성 몇개가 강하게 연관되어 있을 때

# %% [markdown]
# ### **추가) 조기 종료를 사용한 배치 경사 하강법으로 iris 데이터를 활용해 소프트맥스 회귀를 구현해보세요(사이킷런은 사용하지 마세요)**
#
#
# ---
#
# train-test split: 난수를 인덱스로 해서 split
#
#
#
# 소프트맥스 함수 정의
#
#
# 입출력 개수 정하고 비용함수와 그라디언트 공식을 구현
