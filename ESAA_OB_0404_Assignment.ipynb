# %% [markdown]
# <a href="https://colab.research.google.com/github/one-2730/ESSA-25-1/blob/Assignment/ESAA_OB_0404_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##08-07 문서 군집화
#
# 문서 군집화: 비슷한 텍스트 구성의 문서를 군집화
# - 텍스트 분류 기반의 문서 분류와 유사하지만 비지도학습이라서 학습 데이터 세트가 필요 없음!

# %%
import pandas as pd
import glob, os
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)

all_files = glob.glob('topics/*.data')
filename_list = []
opinion_text = []

for file_ in all_files:
  df = pd.read_table(file_, index_col=None, header=0, encoding='latin1')
  filename_ = file_.split('/')[-1]
  filename = filename_.split('.')[0]

  filename_list.append(filename)
  opinion_text.append(df.to_string())

document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
#                          filename  \
# 0      performance_netbook_1005ha
# 1  transmission_toyota_camry_2007
# 2   performance_honda_accord_2008
# 3      voice_garmin_nuvi_255W_gps
# 4     battery-life_netbook_1005ha
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(stop_words='english', ngram_range=(1, 2), min_df=0.05, max_df=0.85)

feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])

# %%
from sklearn.cluster import KMeans

km_cluster = KMeans(n_clusters=5, max_iter=10000, random_state=42)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %%
document_df['cluster_label'] = cluster_label
document_df.head()
# Out:
#                          filename  \
# 0      performance_netbook_1005ha
# 1  transmission_toyota_camry_2007
# 2   performance_honda_accord_2008
# 3      voice_garmin_nuvi_255W_gps
# 4     battery-life_netbook_1005ha
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename').head() #주로 호텔 리뷰
# Out:
#                           filename  \
# 7   bathroom_bestwestern_hotel_sfo
# 6       free_bestwestern_hotel_sfo
# 19         room_holiday_inn_london
# 20     rooms_bestwestern_hotel_sfo
# 44         rooms_swissotel_chicago
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==1].sort_values(by='filename').head() #주로 전자기기 리뷰
# Out:
#                          filename  \
# 11  accuracy_garmin_nuvi_255W_gps
# 5      battery-life_amazon_kindle
# 39     battery-life_ipod_nano_8gb
# 4     battery-life_netbook_1005ha
# 12          buttons_amazon_kindle
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename').head() #주로 토요타, 혼다
# Out:
#                          filename  \
# 8       comfort_honda_accord_2008
# 21      comfort_toyota_camry_2007
# 34  gas_mileage_toyota_camry_2007
# 9      interior_honda_accord_2008
# 13     interior_toyota_camry_2007
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==3].sort_values(by='filename').head() #주로 호텔 리뷰, 킨들이 섞여있음
# Out:
#                           filename  \
# 47  location_bestwestern_hotel_sfo
# 14     location_holiday_inn_london
# 27   parking_bestwestern_hotel_sfo
# 41             price_amazon_kindle
# 36        price_holiday_inn_london
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==4].sort_values(by='filename').head() #주로 호텔... 내비게이션이 섞여있음
# Out:
#                           filename  \
# 49         food_holiday_inn_london
# 22          food_swissotel_chicago
# 18  satellite_garmin_nuvi_255W_gps
# 48   service_bestwestern_hotel_sfo
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
# 군집개수가 너무 많다는걸 위의 결과에서 알 수 있었음 n_clusters=5 -> 3으로 조정

km_cluster = KMeans(n_clusters=3, max_iter=10000, random_state=42)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

document_df['cluster_label'] = cluster_label
document_df.sort_values(by='cluster_label') #-> 군집화가 잘 됨
# Out:
#                            filename  \
# 6        free_bestwestern_hotel_sfo
# 7    bathroom_bestwestern_hotel_sfo
# 14      location_holiday_inn_london
# 31  service_swissotel_hotel_chicago
# 20      rooms_bestwestern_hotel_sfo
# 22           food_swissotel_chicago
# 19          room_holiday_inn_london
# 16       service_holiday_inn_london
# 27    parking_bestwestern_hotel_sfo
# 49          food_holiday_inn_london
# 48    service_bestwestern_hotel_sfo
# 44          rooms_swissotel_chicago
# 46          staff_swissotel_chicago
# 47   location_bestwestern_hotel_sfo
# 36         price_holiday_inn_london
# 33      staff_bestwestern_hotel_sfo
# 29              fonts_amazon_kindle
# 28     display_garmin_nuvi_255W_gps
# 24      screen_garmin_nuvi_255W_gps
# 26                features_windows7
# 40     updates_garmin_nuvi_255W_gps
# 39       battery-life_ipod_nano_8gb
# 42         navigation_amazon_kindle
# 43            screen_netbook_1005ha
# 38         size_asus_netbook_1005ha
# ...

# %% [markdown]
# ###군집별 핵심 단어 추출하기
#
# 군집에 속한 문서는 핵심 단어를 주축으로 군집화됨
#
# KMeans.cluster_centers 속성으로 확인 가능
#
# 이렇게 핵심 단어를 뽑아서 토픽모델링 등에도 사용할 수 있을듯

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers_.shape:', cluster_centers.shape)
print(cluster_centers) #3개의 군집, 4400개의 word 피처: 각 피처의 위치가 개별 중심과 얼마나 가까운지 0에서 1의 숫자로 표현
# Out:
# cluster_centers_.shape: (3, 4400)
# [[0.00446686 0.         0.         ... 0.00165745 0.         0.        ]
#  [0.00155242 0.         0.         ... 0.         0.00048981 0.00873709]
#  [0.000666   0.00511484 0.00347154 ... 0.         0.00208862 0.        ]]

# %%
def get_cluster_details(cluster_model, cluster_data, feature_names, cluster_num, top_n_features=10):
  cluster_details={}
  centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:, ::-1]

  for num in range(cluster_num):
    cluster_details[num] = {}
    cluster_details[num]['cluster'] = num

    top_feature_indexes = centroid_feature_ordered_ind[num, :top_n_features]
    top_features = [feature_names[ind] for ind in top_feature_indexes]

    top_feature_values = cluster_model.cluster_centers_[num, top_feature_indexes].tolist()

    cluster_details[num]['top_features'] = top_features
    cluster_details[num]['top_features_value'] = top_feature_values
    filenames = cluster_data[cluster_data['cluster_label']==num]['filename']
    filenames = filenames.values.tolist()

    cluster_details[num]['filenames'] = filenames

  return cluster_details

# %%
def print_cluster_details(cluster_details):
  for cluster_num, cluster_detail in cluster_details.items():
    print('##### cluster {0}'.format(cluster_num))
    print('Top features:', cluster_detail['top_features'])
    print('Reviews 파일명:', cluster_detail['filenames'][:7])
    print('============================================')

# %%
feature_names = tfidf_vect.get_feature_names_out()

cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=document_df, feature_names=feature_names, cluster_num=3, top_n_features=10)
print_cluster_details(cluster_details)
# Out:
# ##### cluster 0
# Top features: ['hotel', 'service', 'rooms', 'staff', 'room', 'food', 'location', 'clean', 'bathroom', 'parking']
# Reviews 파일명: ['free_bestwestern_hotel_sfo', 'bathroom_bestwestern_hotel_sfo', 'location_holiday_inn_london', 'service_holiday_inn_london', 'room_holiday_inn_london', 'rooms_bestwestern_hotel_sfo', 'food_swissotel_chicago']
# ...
# ##### cluster 1
# Top features: ['screen', 'battery', 'keyboard', 'kindle', 'battery life', 'directions', 'life', 'size', 'voice', 'features']
# Reviews 파일명: ['voice_garmin_nuvi_255W_gps', 'battery-life_netbook_1005ha', 'battery-life_amazon_kindle', 'keyboard_netbook_1005ha', 'accuracy_garmin_nuvi_255W_gps', 'buttons_amazon_kindle', 'speed_garmin_nuvi_255W_gps']
# ...
# ##### cluster 2
# Top features: ['interior', 'performance', 'mileage', 'seats', 'comfortable', 'gas', 'quality', 'gas mileage', 'transmission', 'car']
# ...
